# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import glob
import datetime
from cmocean import cm as cmo

# %%
ctffles=glob.glob(os.path.join('c:/','Users','sa01ld','OneDrive - SAMS','Instruments','EcoSub','milli_data_20221018','*Valeport_CTF*'))

for fle in ctffles:
    filesize = os.path.getsize(fle)

    if filesize == 0:
        print("file " +fle+" is EMPTY: " + str(filesize))
    else:
        print("file " +fle+" HAS DATA: " + str(filesize))
        df = pd.read_csv(fle,sep=';',header=None,names=["Time", "Temp", "Cond", "Depth", "Fluor"])

# %%
df
# Out:
#                Time  Latitude  Longitude  Estimated forward speed  RPM  \
# 0      1.666018e+09 -4.000238  60.000153                      0.0    0
# 1      1.666018e+09 -4.000238  60.000153                      0.0    0
# 2      1.666018e+09 -4.000238  60.000153                      0.0    0
# 3      1.666018e+09 -4.000238  60.000153                      0.0    0
# 4      1.666018e+09 -4.000238  60.000153                      0.0    0
# ...             ...       ...        ...                      ...  ...
# 57578  1.666021e+09 -4.000426  59.998262                      0.0    0
# 57579  1.666021e+09 -4.000426  59.998262                      0.0    0
# 57580  1.666021e+09 -4.000426  59.998262                      0.0    0
# 57581  1.666021e+09 -4.000426  59.998262                      0.0    0
# 57582  1.666021e+09 -4.000426  59.998262                      0.0    0
#
#         Heading     Depth   Pitch  Pitch rate    Roll  Rudder angle  \
# 0      322.0625 -0.045557  2.7500           0 -3.0625      4.926317
# 1      320.0000 -0.045557 -1.0625           0 -1.0625      4.926317
# 2      320.0000 -0.040553 -1.0625           0 -1.0625      4.926317
# 3      320.0000 -0.040553 -1.0625           0 -1.0625      4.926317
# 4      321.3125 -0.040553 -1.7500           0  0.0000      4.926317
# ...         ...       ...     ...         ...     ...           ...
# 57578  243.0000 -0.020012 -0.1250           0 -6.6250     55.610531
# 57579  242.1875 -0.020012 -0.4375           0 -6.8125     55.610531
# 57580  242.1875 -0.044950 -0.4375           0 -6.8125     55.610531
# 57581  242.1875 -0.044950 -0.4375           0 -6.8125     55.610531
# 57582  242.1875 -0.044950 -0.4375           0 -6.8125     55.610531
#
#        Position of the moving mass  Dead reckoner
# 0                               50              1
# 1                               50              1
# 2                               50              1
# 3                               50              1
# 4                               50              1
# ...                            ...            ...
# 57578                           50              1
# 57579                           50              1
# 57580                           50              1
# 57581                           50              1
# 57582                           50              1
#
# [57583 rows x 13 columns]
